# %%
# setup google colab in this video
# https://www.youtube.com/watch?v=DsGd2e9JNH4
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
import sys
FOLDERNAME="UNET_Segmentation"
assert FOLDERNAME is not None, "[!] Enter the foldername."
path='/content/gdrive/MyDrive/{}'.format(FOLDERNAME)
sys.path.append(path)


#change working directory to UnetSegmantion
# %cd {path}

# remove bad hidden files from mac 
# !find . -name ".DS_Store"|xargs --no-run-if-empty rm
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/UNET_Segmentation

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/UNET_Segmentation

# %%
# change runtime, shoulb be true
# https://stackoverflow.com/questions/59154623/torch-cuda-is-available-returns-false-in-colab
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python train.py
# Out:
# 100% 255/255 [10:23<00:00,  2.45s/it]
# Saving checkpoint...
# Got 97658627/99090432 with acc 98.56
# Dice score: 0.9669286608695984
# 100% 255/255 [05:04<00:00,  1.19s/it]
# Saving checkpoint...
# Got 98377013/99090432 with acc 99.28
# Dice score: 0.9832894206047058
# 100% 255/255 [05:04<00:00,  1.20s/it]
# Saving checkpoint...
# Got 98298646/99090432 with acc 99.20
# Dice score: 0.9814697504043579
# 100% 255/255 [05:04<00:00,  1.19s/it]
# Saving checkpoint...
# Got 98597949/99090432 with acc 99.50
# Dice score: 0.9884475469589233
# 100% 255/255 [05:05<00:00,  1.20s/it]
# Saving checkpoint...
# Got 97981841/99090432 with acc 98.88
# Dice score: 0.9745693802833557
# 100% 255/255 [05:04<00:00,  1.19s/it]
# Saving checkpoint...
# Got 98173464/99090432 with acc 99.07
# Dice score: 0.9788575768470764
# 100% 255/255 [05:04<00:00,  1.20s/it]
# Saving checkpoint...
# Got 98650524/99090432 with acc 99.56
# Dice score: 0.9896777272224426
# 100% 255/255 [05:05<00:00,  1.20s/it]
# ...

# %%
# !python dataset.py
# Out:
# 4080
# torch.Size([3, 160, 240])
# torch.Size([160, 240])
# torch.Size([3, 160, 240]) torch.Size([160, 240])
# loader:
# 255
# torch.Size([16, 3, 160, 240]) torch.Size([16, 160, 240])

# %%
a = (1,2)
print(a)
# Out:
# (1, 2)

# %%
print("A")

# %%
# !python train.py
# Out:
# python3: can't open file 'train.py': [Errno 107] Transport endpoint is not connected

# %%
from model import *
